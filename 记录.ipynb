# %%
CUDA_VISIBLE_DEVICES=0 torchrun --master_port=6666 --nproc_per_node=1 main.py \
--model vim_tiny_patch16_stride8_224_bimambav2_final_pool_mean_abs_pos_embed_with_midclstok_div2 --batch-size 32 \
--drop-path 0.05 --weight-decay 0.05 --lr 5e-4 --num_workers 1 \
--data-path ../../autodl-tmp/NewThree_Dataset \
--output_dir ./output/vim_small_patch16_224_bimambav2_final_pool_mean_abs_pos_embed_with_midclstok_div2 \
--no_amp

# %% [markdown]
# ![企业微信截图_17269157464217.png](attachment:0c16b1e2-fc41-4255-bea5-a386ff5a24cb.png)

# %% [markdown]
# ![image.png](attachment:aec2c361-c941-42a2-a633-b9e6fbd5646f.png)

# %%
import zipfile
import os

zip_path = '/root/autodl-fs/NewThree_Dataset.zip'  # 压缩包路径
extract_path = './'  # 解压到这个文件夹

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("解压完成")
# Out:
# 解压完成
